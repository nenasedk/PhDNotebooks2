# %%
import sys,os
import glob
import numpy as np

import matplotlib.pyplot as plt
from matplotlib.ticker import StrMethodFormatter
import petitRADTRANS.retrieval.plot_style

from astropy.io import fits
from scipy.ndimage import rotate
from photutils import CircularAperture, CircularAnnulus, aperture_photometry
# Out:
# WARNING:param.main: pandas could not register all extension types imports failed with the following error: cannot import name 'ABCIndexClass' from 'pandas.core.dtypes.generic' (/Users/nasedkin/anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/generic.py)
# Using pRT Plotting style!

# %%
data_dir = "/Users/nasedkin/Documents/HR8799/ALES/"
new_datadir = "/Users/nasedkin/Downloads/"
sm = np.genfromtxt(data_dir+"HR8799A_flux.txt",delimiter=',').T
new_specs = np.genfromtxt(new_datadir + "HR_8799_LBT_vAPP_final_spectra_3362-4144nm.txt").T
print(new_specs.shape)
filelist = sorted(glob.glob(data_dir + "*out.fits"))
hduls = []
for f in filelist:
    hdu = fits.open(f)
    hduls.append(hdu)
    print(hdu.info())
# Out:
# (7, 57)
# Filename: /Users/nasedkin/Documents/HR8799/ALES/ALES_HR8799c_out.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      10   (48, 48)   float64
#   1                1 BinTableHDU     17   48R x 3C   [D, D, D]
# None
# Filename: /Users/nasedkin/Documents/HR8799/ALES/ALES_HR8799d_out.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      10   (49, 49)   float64
#   1                1 BinTableHDU     17   49R x 3C   [D, D, D]
# None
# Filename: /Users/nasedkin/Documents/HR8799/ALES/ALES_HR8799e_out.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      10   (49, 49)   float64
#   1                1 BinTableHDU     17   49R x 3C   [D, D, D]
# None

# %%
fig, ax = plt.subplots()
for h in hduls:
    print(h[1].columns)
    ax.errorbar(h[1].data['wavelength'],h[1].data['apparent flux'],yerr = h[1].data['apparent flux error'], c = 'k')
print(new_specs.shape)
# Out:
# ColDefs(
#     name = 'wavelength'; format = 'D'; unit = 'um'
#     name = 'apparent flux'; format = 'D'; unit = 'mJy'
#     name = 'apparent flux error'; format = 'D'; unit = 'mJy'
# )
# ColDefs(
#     name = 'wavelength'; format = 'D'; unit = 'um'
#     name = 'apparent flux'; format = 'D'; unit = 'mJy'
#     name = 'apparent flux error'; format = 'D'; unit = 'mJy'
# )
# ColDefs(
#     name = 'wavelength'; format = 'D'; unit = 'um'
#     name = 'apparent flux'; format = 'D'; unit = 'mJy'
#     name = 'apparent flux error'; format = 'D'; unit = 'mJy'
# )
# (7, 57)
