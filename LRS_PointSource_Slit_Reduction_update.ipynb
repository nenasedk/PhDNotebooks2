# %% [markdown]
# # MIRI LRS Slit Spectroscopy: Spectral Extraction
#
# ### Author, Date
#
# Sarah Kendrew, ESA and STScI MIRI Branch, sarah.kendrew@esa.int</br>
# March 2023
#
#
# ### <span style="color:red">Tl;dr?</span>
#
# <span style="color:red">**Want pretty spectra, don't want to read all the words? Grab the abbreviated version of this notebook in script form, miri_lrs_extract_L3.py**.
# </span>
#
#
# ### Spectral extraction issues
#
# The automated spectra extraction in the JWST calibration pipeline is very sensitive to coordinate inaccuracies, and as a result, the extract (``x1d``) products in MAST are often of poor quality. Specifically, the ``extract_1d`` step does not reliably place the extraction aperture in the correct place on the array. The algorithm uses the target coordinates in the metadata and the WCS information to place the aperture at the location of the target; the algorithm itself is actually very effective, but as it relies on accurate coordinate information both in the header and in the data WCS information, it is very sensitive to coordinate registration issues. Reasons for such coordinate issues are e.g.:
#
# * inaccuracies in the guide star coordinates that cause the RA, Dec registration of the field to be ofset
# * coordinate tarnsformation inaccuracies when resampling
# * target coordinate errors
#
# We are actively working on resolving these issues, and in the mean time are updating the specral extraction process to extract based on detector position rather than WCS location.
#
# **In this notebook we will demo how to perform a more accurate extraction manually using the JWST pipeline, for LEVEL 3 data**.
#
#
# ### Aims
#
# This notebook will demonstrate how to get a well-calibrated and extracted spectrum from a Low-Resolution Spectroscopy (LRS) observation of a point source in the slit. We have chosen as example data an observation where the extracted products in MAST are affected by the above issues, and don't look right.
#
# We are actively working on improving the robustness of the spectral extraction algorithms. In the mean time, this notebook provides a template for how to work around the extraction issues and produce clean, well-extracted spectra. We will provide additional explanation along the way.
#
#
# ### Assumptions
#
# We will start from the Level 2a data. This is the file ending in ``rate.fits``. This data product has undergone basic detector calibration. The units are DN/s.
#
# The calibration steps assume the target is an unresolved point source, and that the observation used the ALONG SLIT NOD dither pattern.
#
# **The custom extraction is applied at the Level 3 stage of the pipeline. We include the Spec2Pipeline to provide some extra info & context, but you can also jump in just for the Spec3Pipeline.**
#
#
# ### Test data
#
# The data used in this notebook is an observation of the Type Ia supernova SN2021aefx, observed by Jha et al in PID 2072 (Obs 1), **where the automated spectral extraction failed**. These data were taken with zero exclusive access period, and published in [Kwok et al 2023](https://ui.adsabs.harvard.edu/abs/2023ApJ...944L...3K/abstract). You can retrieve the data from [this Box folder](https://stsci.box.com/s/i2xi18jziu1iawpkom0z2r94kvf9n9kb), and we recommend you place the files in the ``data/`` folder of this repository, or change the directory settings in the notebook prior to running.
#
# You can of course just use your own data instead of the demo data.
#
# ### CRDS pmap 1088 update (May 2023)
#
# **The LRS spectral extraction reference file updated in May 2023, starting from CRDS context (pmap) 1088, to address the issue described in this notebook.**
#
# We will set the context explicitly to pmap 1084, so the pipeline outputs demonstrate the problem prior to the fix. You can see the effect of the update by changing the CRDS context number to a more recent version in the cell below.
#
# If your CRDS context is 1088 or higher, the LRS spectral extraction reference file used will have fixed coordinates specified as the extraction aperture. These coordinates are tailored to the Stage 3 Pipeline extraction (i.e. the dither-combined, resampled product), and the Level 3 products in MAST should be much improved. However, as the same extraction reference file is used for both the Stage 2 and Stage 3 iterations of ``extract_1d()``, the Level 2b extracted spectra will not be accurate.
#
# If you want to examine the individual nod extracted spectra, use the methods demonstrated in this notebook to create a custom extraction file tailored to the 2D spectral images you'd like to extract, and run the step standalone.

# %%
import os
os.environ['CRDS_CONTEXT'] = 'jwst_1084.pmap'

# %%
from glob import glob

import numpy as np
import matplotlib.pyplot as plt

#TRY opencv-python == 4.6.0.66 BAD
#== 4.5.5.64 BAD
#== 4.4.0.46 GOOD
import jwst
from jwst.pipeline import Spec2Pipeline, Spec3Pipeline
from jwst import datamodels

print('Using JWST calibration pipeline version {0}'.format(jwst.__version__))
# Out:
# Using JWST calibration pipeline version 1.11.1

# %% [markdown]
# Let's start by plotting the default Level 3 extracted output file that can be retrieved from MAST. We restrict the short-wavelength end of the x-axis to 5 micron, as our calibration is very poor below this wavelength. **This is not the spectrum we are expecting**.

# %%
import cv2

# %%
l3_file = 'data/yses1c_miri/jw02044-o006_t003_miri_p750l_x1d.fits'
l3_spec = datamodels.open(l3_file)

fig, ax = plt.subplots(figsize=[12,4])
ax.plot(l3_spec.spec[0].spec_table['WAVELENGTH'], l3_spec.spec[0].spec_table['FLUX'])
ax.set_xlabel('wavelength (um)')
ax.set_ylabel('flux (Jy)')
ax.set_title('YSES1c - Level 3 spectrum in MAST')
ax.set_xlim(5., 14.)
ax.set_ylim(-0.00015,0.00015)
fig.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[6], line 2
#       1 l3_file = 'data/yses1c_miri/jw02044-o006_t003_miri_p750l_x1d.fits'
# ----> 2 l3_spec = datamodels.open(l3_file)
#       4 fig, ax = plt.subplots(figsize=[12,4])
#       5 ax.plot(l3_spec.spec[0].spec_table['WAVELENGTH'], l3_spec.spec[0].spec_table['FLUX'])
#
# File ~/anaconda3/envs/jwst-3-9/lib/python3.9/site-packages/stdatamodels/jwst/datamodels/util.py:130, in open(init, guess, memmap, **kwargs)
#     127 file_type = filetype.check(init)
#     129 if file_type == "fits":
# --> 130     hdulist = fits.open(init, memmap=memmap)
#     131     file_to_close = hdulist
#     133 elif file_type == "asn":
#     134     # Read the file as an association / model container
#
# File ~/anaconda3/envs/jwst-3-9/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:213, in fitsopen(name, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#     210 if not name:
#     211     raise ValueError(f"Empty filename: {name!r}")
# --> 213 return HDUList.fromfile(
#     214     name,
#     215     mode,
#     216     memmap,
#     217     save_backup,
#     218     cache,
#     219     lazy_load_hdus,
#     220     ignore_missing_simple,
#     221     use_fsspec=use_fsspec,
#     222     fsspec_kwargs=fsspec_kwargs,
#     223     **kwargs,
#     224 )
#
# File ~/anaconda3/envs/jwst-3-9/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:476, in HDUList.fromfile(cls, fileobj, mode, memmap, save_backup, cache, lazy_load_hdus, ignore_missing_simple, **kwargs)
#     457 @classmethod
#     458 def fromfile(
#     459     cls,
#    (...)
#     467     **kwargs,
#     468 ):
#     469     """
#     470     Creates an `HDUList` instance from a file-like object.
#     471
#    (...)
#     474     documentation for details of the parameters accepted by this method).
#     475     """
# --> 476     return cls._readfrom(
#     477         fileobj=fileobj,
#     478         mode=mode,
#     479         memmap=memmap,
#     480         save_backup=save_backup,
#     481         cache=cache,
#     482         ignore_missing_simple=ignore_missing_simple,
#     483         lazy_load_hdus=lazy_load_hdus,
#     484         **kwargs,
#     485     )
#
# File ~/anaconda3/envs/jwst-3-9/lib/python3.9/site-packages/astropy/io/fits/hdu/hdulist.py:1146, in HDUList._readfrom(cls, fileobj, data, mode, memmap, cache, lazy_load_hdus, ignore_missing_simple, use_fsspec, fsspec_kwargs, **kwargs)
#    1143 if fileobj is not None:
#    1144     if not isinstance(fileobj, _File):
#    1145         # instantiate a FITS file object (ffo)
# -> 1146         fileobj = _File(
#    1147             fileobj,
#    1148             mode=mode,
#    1149             memmap=memmap,
#    1150             cache=cache,
#    1151             use_fsspec=use_fsspec,
#    1152             fsspec_kwargs=fsspec_kwargs,
#    1153         )
#    1154     # The Astropy mode is determined by the _File initializer if the
#    1155     # supplied mode was None
#    1156     mode = fileobj.mode
#
# File ~/anaconda3/envs/jwst-3-9/lib/python3.9/site-packages/astropy/io/fits/file.py:217, in _File.__init__(self, fileobj, mode, memmap, overwrite, cache, use_fsspec, fsspec_kwargs)
#     215     self._open_fileobj(fileobj, mode, overwrite)
#     216 elif isinstance(fileobj, (str, bytes)):
# --> 217     self._open_filename(fileobj, mode, overwrite)
#     218 else:
#     219     self._open_filelike(fileobj, mode, overwrite)
#
# File ~/anaconda3/envs/jwst-3-9/lib/python3.9/site-packages/astropy/io/fits/file.py:626, in _File._open_filename(self, filename, mode, overwrite)
#     623 ext = os.path.splitext(self.name)[1]
#     625 if not self._try_read_compressed(self.name, magic, mode, ext=ext):
# --> 626     self._file = open(self.name, IO_FITS_MODES[mode])
#     627     self.close_on_error = True
#     629 # Make certain we're back at the beginning of the file
#     630 # BZ2File does not support seek when the file is open for writing, but
#     631 # when opening a file for write, bz2.BZ2File always truncates anyway.
#
# FileNotFoundError: [Errno 2] No such file or directory: 'data/yses1c_miri/jw02044-o006_t003_miri_p750l_x1d.fits'

# %% [markdown]
# ## Spec2Pipeline
#
# The sequence of steps for the LRS slit mode in the Spec2Pipeline is as follows:
#
# * ``assign_wcs``: assigns the world coordinate system extension as well as the wavelength calibration
# * ``background``: performs background subtraction
# * ``source_type``: assigns a source type. This is inherited from APT, or if not marked in APT as unknown, it will take a pre-selected default value. For MIRI LRS the default value is ``point``.
# * ``flat_field``: divides the science data by the flat field
# * ``pathloss``: corrects for wavelength-dependent flux loss due to the truncation by the slit
# * ``photom``: converts DN/s pixel values to MJy/sr physical flux densities
# * ``extract_1d``: performs spectral extraction. At this stage of the pipeline, the extraction is performed on each nod file separately; these are not yet the _final_ extracted products.
#
#
#
# ### Association vs. single file input
#
# A single ``rate`` file can be passed to this pipeline stage or any of its individual steps, and be processed successfully. However, for our default use case of a point source observation using the ALONG SLIT NOD pattern, the input to the Spec2Pipeline is an **association file**, which contains information for both files. The pipeline builds such files for all cases where multiple files need to be combined for pipeline execution. In the case of LRS slit observations, the ``background`` step performs a mutual subtraction of the nods.
#
# The association files used can also be downloaded from MAST. We demonstrate here how to build them from scratch using the tools provided in the pipeline package. You can read more about associations [here](https://jwst-pipeline.readthedocs.io/en/latest/jwst/associations/level2_asn_technical.html).

# %%
from jwst.associations.asn_from_list import asn_from_list
from jwst.associations.lib.rules_level2_base import DMSLevel2bBase

# %%
nod1_file = 'data/yses1c_miri/jw02044006001_06101_00001_mirimage_rate.fits'
nod2_file = 'data/yses1c_miri/jw02044006001_06101_00002_mirimage_rate.fits'

nods_list = [nod1_file, nod2_file]

# %%
asn = asn_from_list(nods_list, rule=DMSLevel2bBase, meta={'program':'2044', 'target':'YSES1c', 'asn_pool':'None'})
print(asn)
# Out:
# Association jw2044-o999_none_00002_asn
#     Parameters:        Product type: indetermined        Rule:         indetermined        Program:      indetermined        Target:       indetermined        Pool:         indetermined
#
# 	data/yses1c_miri/jw02044006001_06101_00001_mirimage with 1 members
# 	data/yses1c_miri/jw02044006001_06101_00002_mirimage with 1 members

# %% [markdown]
# This association now contains 2 _members_. We will provide each member exposure with its associated background, i.e. the opposite nod file, and write the association to file.

# %%
asn['products'][0]['name'] = nod1_file.split('/')[-1]
asn['products'][1]['name'] = nod2_file.split('/')[-1]
asn['products'][0]['members'].append({'expname': nod2_file, 'exptype':'background'})
asn['products'][1]['members'].append({'expname': nod1_file, 'exptype':'background'})

print(asn)

# write this out to a json file
with open('lrs_slit_test_spec2asn.json', 'w') as fp:
    fp.write(asn.dump()[1])
# Out:
# 2023-06-14 12:15:05,285 - stpipe - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
# Association jw2044-o999_none_00002_asn
#     Parameters:        Product type: indetermined        Rule:         indetermined        Program:      indetermined        Target:       indetermined        Pool:         indetermined
#
# 	jw02044006001_06101_00001_mirimage_rate.fits with 2 members
# 	jw02044006001_06101_00002_mirimage_rate.fits with 2 members

# %% [markdown]
# ### Running the Spec2Pipeline
#
#
# We set up and run the Spec2Pipeline, using the association file as input.

# %%
spec2 = Spec2Pipeline()

#assign wcs 
spec2.assign_wcs.skip = False
spec2.assign_wcs.save_results = True
#background subtract
spec2.bkg_subtract.skip = False
spec2.bkg_subtract.save_results = True
#source type
spec2.srctype.source_type = 'POINT' #Brittany had this for VHS bc it was missing from header
#pathloss 
spec2.pathloss.skip = False
spec2.pathloss.save_results = True
#photom
spec2.photom.skip = False
spec2.photom.save_results = True
#extract 1d
spec2.extract_1d.skip = False
spec2.extract_1d.save_results = True
#pixel replace
# spec2.pixel_replace.skip = False
# spec2.pixel_replace.save_results = True
#resample
spec2.resample_spec.skip = True
spec2.resample_spec.save_results = True
#flat field
spec2.flat_field.skip = False
spec2.flat_field.save_results = True

spec2.save_results = True
spec2.output_dir = 'stage2/'

sp2_out = spec2.run('lrs_slit_test_spec2asn.json')
# Out:
# 2023-06-15 12:03:00,967 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2023-06-15 12:03:00,968 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2023-06-15 12:03:00,969 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2023-06-15 12:03:00,970 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2023-06-15 12:03:00,971 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2023-06-15 12:03:00,972 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2023-06-15 12:03:00,974 - stpipe.Spec2Pipeline.master_background_mos - INFO - MasterBackgroundMosStep instance created.
# 2023-06-15 12:03:00,975 - stpipe.Spec2Pipeline.master_background_mos.flat_field - INFO - FlatFieldStep instance created.
# 2023-06-15 12:03:00,975 - stpipe.Spec2Pipeline.master_background_mos.pathloss - INFO - PathLossStep instance created.
# 2023-06-15 12:03:00,976 - stpipe.Spec2Pipeline.master_background_mos.barshadow - INFO - BarShadowStep instance created.
# 2023-06-15 12:03:00,977 - stpipe.Spec2Pipeline.master_background_mos.photom - INFO - PhotomStep instance created.
# 2023-06-15 12:03:00,977 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2023-06-15 12:03:00,978 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2023-06-15 12:03:00,979 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2023-06-15 12:03:00,980 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2023-06-15 12:03:00,981 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2023-06-15 12:03:00,981 - stpipe.Spec2Pipeline.residual_fringe - INFO - ResidualFringeStep instance created.
# 2023-06-15 12:03:00,982 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2023-06-15 12:03:00,983 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2023-06-15 12:03:00,984 - stpipe.Spec2Pipeline.wfss_contam - INFO - WfssContamStep instance created.
# 2023-06-15 12:03:00,985 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2023-06-15 12:03:00,986 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2023-06-15 12:03:00,987 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2023-06-15 12:03:00,989 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2023-06-15 12:03:01,112 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('lrs_slit_test_spec2asn.json',).
# 2023-06-15 12:03:01,120 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage2/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'fail_on_exception': True, 'save_wfss_esec': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'imprint_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'msa_flagging': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'extract_2d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': None, 'wfss_nbright': 1000}, 'master_background_mos': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}}}, 'wavecorr': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': Fals ...
# 2023-06-15 12:03:01,131 - stpipe.Spec2Pipeline - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2023-06-15 12:03:01,172 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw02044006001_06101_00001_mirimage_rate.fits' reftypes = ['apcorr', 'area', 'barshadow', 'camera', 'collimator', 'cubepar', 'dflat', 'disperser', 'distortion', 'extract1d', 'fflat', 'filteroffset', 'flat', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'mrsxartcorr', 'msa', 'msaoper', 'ote', 'pathloss', 'photom', 'regions', 'sflat', 'speckernel', 'specprofile', 'spectrace', 'specwcs', 'wavecorr', 'wavelengthrange', 'wavemap', 'wfssbkg']
# 2023-06-15 12:03:01,175 - stpipe.Spec2Pipeline - INFO - Prefetch for APCORR reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_apcorr_0007.fits'.
# 2023-06-15 12:03:01,176 - stpipe.Spec2Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2023-06-15 12:03:01,176 - stpipe.Spec2Pipeline - INFO - Prefetch for BARSHADOW reference file is 'N/A'.
# 2023-06-15 12:03:01,176 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2023-06-15 12:03:01,177 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2023-06-15 12:03:01,177 - stpipe.Spec2Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2023-06-15 12:03:01,177 - stpipe.Spec2Pipeline - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2023-06-15 12:03:01,178 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2023-06-15 12:03:01,178 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_distortion_0047.asdf'.
# 2023-06-15 12:03:01,178 - stpipe.Spec2Pipeline - INFO - Prefetch for EXTRACT1D reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2023-06-15 12:03:01,179 - stpipe.Spec2Pipeline - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2023-06-15 12:03:01,179 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2023-06-15 12:03:01,179 - stpipe.Spec2Pipeline - INFO - Prefetch for FLAT reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_flat_0790.fits'.
# 2023-06-15 12:03:01,179 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is 'N/A'.
# 2023-06-15 12:03:01,180 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is 'N/A'.
# 2023-06-15 12:03:01,180 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2023-06-15 12:03:01,180 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2023-06-15 12:03:01,180 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2023-06-15 12:03:01,180 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2023-06-15 12:03:01,181 - stpipe.Spec2Pipeline - INFO - Prefetch for MRSXARTCORR reference file is 'N/A'.
# 2023-06-15 12:03:01,181 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is 'N/A'.
# 2023-06-15 12:03:01,181 - stpipe.Spec2Pipeline - INFO - Prefetch for MSAOPER reference file is 'N/A'.
# 2023-06-15 12:03:01,181 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is 'N/A'.
# 2023-06-15 12:03:01,181 - stpipe.Spec2Pipeline - INFO - Prefetch for PATHLOSS reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_pathloss_0001.fits'.
# 2023-06-15 12:03:01,182 - stpipe.Spec2Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_photom_0085.fits'.
# 2023-06-15 12:03:01,182 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2023-06-15 12:03:01,182 - stpipe.Spec2Pipeline - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2023-06-15 12:03:01,183 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2023-06-15 12:03:01,183 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2023-06-15 12:03:01,183 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2023-06-15 12:03:01,183 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_specwcs_0005.fits'.
# 2023-06-15 12:03:01,184 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is 'N/A'.
# 2023-06-15 12:03:01,184 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2023-06-15 12:03:01,184 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2023-06-15 12:03:01,184 - stpipe.Spec2Pipeline - INFO - Prefetch for WFSSBKG reference file is 'N/A'.
# 2023-06-15 12:03:01,185 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2023-06-15 12:03:01,190 - stpipe.Spec2Pipeline - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2023-06-15 12:03:01,190 - stpipe.Spec2Pipeline - INFO - Processing product jw02044006001_06101_00001_mirimage_rate.fits
# 2023-06-15 12:03:01,191 - stpipe.Spec2Pipeline - INFO - Working on input data/yses1c_miri/jw02044006001_06101_00001_mirimage_rate.fits ...
# 2023-06-15 12:03:01,329 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_rate.fits>,).
# 2023-06-15 12:03:01,330 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2023-06-15 12:03:01,535 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 1.0000201609870145
# 2023-06-15 12:03:01,538 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a MIRI mir_lrs-fixedslit pipeline with references {'distortion': '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': None, 'specwcs': '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_specwcs_0005.fits', 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2023-06-15 12:03:01,592 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  201.296858087 -64.939879171 201.296858087 -64.939392586 201.299996909 -64.939392586 201.299996909 -64.939879171
# 2023-06-15 12:03:01,592 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.296858087 -64.939879171 201.296858087 -64.939392586 201.299996909 -64.939392586 201.299996909 -64.939879171
# 2023-06-15 12:03:01,592 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2023-06-15 12:03:01,731 - stpipe.Spec2Pipeline.assign_wcs - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_assign_wcs.fits
# 2023-06-15 12:03:01,732 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2023-06-15 12:03:01,842 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_assign_wcs.fits>, []).
# 2023-06-15 12:03:01,843 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:01,843 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2023-06-15 12:03:01,844 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2023-06-15 12:03:01,948 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('data/yses1c_miri/jw02044006001_06101_00002_mirimage_rate.fits', []).
# 2023-06-15 12:03:01,948 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'imprint_subtract', 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:01,949 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2023-06-15 12:03:01,949 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2023-06-15 12:03:02,051 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_assign_wcs.fits>, ['data/yses1c_miri/jw02044006001_06101_00002_mirimage_rate.fits']).
# 2023-06-15 12:03:02,052 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'bsub', 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2023-06-15 12:03:02,100 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from data/yses1c_miri/jw02044006001_06101_00002_mirimage_rate.fits
# 2023-06-15 12:03:02,138 - stpipe.Spec2Pipeline.bkg_subtract - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/astropy/stats/sigma_clipping.py:367: AstropyUserWarning: Input data contains invalid values (NaNs or infs), which were automatically clipped.
#   warnings.warn(
#
# 2023-06-15 12:03:02,401 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_bsub.fits
# 2023-06-15 12:03:02,402 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2023-06-15 12:03:02,513 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_bsub.fits>,).
# 2023-06-15 12:03:02,514 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:02,515 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2023-06-15 12:03:02,516 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2023-06-15 12:03:02,626 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_bsub.fits>,).
# 2023-06-15 12:03:02,627 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2023-06-15 12:03:02,632 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:02,632 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2023-06-15 12:03:02,632 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2023-06-15 12:03:02,635 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2023-06-15 12:03:02,744 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_bsub.fits>,).
# 2023-06-15 12:03:02,745 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:02,746 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2023-06-15 12:03:02,747 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2023-06-15 12:03:02,849 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_bsub.fits>,).
# 2023-06-15 12:03:02,850 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2023-06-15 12:03:02,922 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:02,922 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:02,922 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:02,934 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:03,176 - stpipe.Spec2Pipeline.flat_field - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_flat_field.fits
# 2023-06-15 12:03:03,177 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2023-06-15 12:03:03,290 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_flat_field.fits>,).
# 2023-06-15 12:03:03,291 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:03,291 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2023-06-15 12:03:03,293 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2023-06-15 12:03:03,402 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_flat_field.fits>,).
# 2023-06-15 12:03:03,403 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2023-06-15 12:03:03,413 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_pathloss_0001.fits
# 2023-06-15 12:03:03,437 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:03,781 - stpipe.Spec2Pipeline.pathloss - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_pathloss.fits
# 2023-06-15 12:03:03,782 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2023-06-15 12:03:03,895 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_pathloss.fits>,).
# 2023-06-15 12:03:03,895 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2023-06-15 12:03:03,896 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2023-06-15 12:03:03,897 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2023-06-15 12:03:04,011 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_pathloss.fits>,).
# 2023-06-15 12:03:04,011 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2023-06-15 12:03:04,027 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_photom_0085.fits
# 2023-06-15 12:03:04,028 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2023-06-15 12:03:04,089 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2023-06-15 12:03:04,090 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2023-06-15 12:03:04,090 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:04,090 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2023-06-15 12:03:04,107 - stpipe.Spec2Pipeline.photom - INFO -  subarray: FULL
# 2023-06-15 12:03:04,107 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 13.7913
# 2023-06-15 12:03:04,308 - stpipe.Spec2Pipeline.photom - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_photom.fits
# 2023-06-15 12:03:04,308 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2023-06-15 12:03:04,421 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00001_mirimage_photom.fits>,).
# 2023-06-15 12:03:04,422 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'residual_fringe', 'search_output_file': False, 'input_dir': '', 'save_intermediate_results': False, 'ignore_region_min': None, 'ignore_region_max': None}
# 2023-06-15 12:03:04,422 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step skipped.
# 2023-06-15 12:03:04,424 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe done
# 2023-06-15 12:03:04,596 - stpipe.Spec2Pipeline.resample_spec - INFO - Step resample_spec running with args (<ImageModel(1024, 1032) from stage2/jw02044006001_06101_00001_mirimage_cal.fits>,).
# 2023-06-15 12:03:04,597 - stpipe.Spec2Pipeline.resample_spec - INFO - Step resample_spec parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 's2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2023-06-15 12:03:04,597 - stpipe.Spec2Pipeline.resample_spec - INFO - Step skipped.
# 2023-06-15 12:03:04,599 - stpipe.Spec2Pipeline.resample_spec - INFO - Step resample_spec done
# 2023-06-15 12:03:04,792 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ImageModel(1024, 1032) from stage2/jw02044006001_06101_00001_mirimage_cal.fits>,).
# 2023-06-15 12:03:04,794 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-06-15 12:03:04,805 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2023-06-15 12:03:04,811 - stpipe.Spec2Pipeline.extract_1d - INFO - Using APCORR file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_apcorr_0007.fits
# 2023-06-15 12:03:04,836 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2023-06-15 12:03:04,836 - stpipe.Spec2Pipeline.extract_1d - INFO - Processing spectral order 1
# 2023-06-15 12:03:04,837 - stpipe.Spec2Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:04,848 - stpipe.Spec2Pipeline.extract_1d - INFO - Applying position offset of -9.55 to xstart and xstop
# 2023-06-15 12:03:04,848 - stpipe.Spec2Pipeline.extract_1d - INFO - Using extraction limits: xstart=309.95006391050254, xstop=319.95006391050254, ystart=6, ystop=395
# 2023-06-15 12:03:04,853 - stpipe.Spec2Pipeline.extract_1d - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/extract_1d/extract.py:1901: RuntimeWarning: Mean of empty slice
#   wavelength = np.nanmean(wl[sy0:sy1, sx0:sx1], axis=1)
#
# 2023-06-15 12:03:04,907 - stpipe.Spec2Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2023-06-15 12:03:05,107 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_x1d.fits
# 2023-06-15 12:03:05,107 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-06-15 12:03:05,107 - stpipe.Spec2Pipeline - INFO - Finished processing product jw02044006001_06101_00001_mirimage_rate.fits
# 2023-06-15 12:03:05,108 - stpipe.Spec2Pipeline - INFO - Processing product jw02044006001_06101_00002_mirimage_rate.fits
# 2023-06-15 12:03:05,108 - stpipe.Spec2Pipeline - INFO - Working on input data/yses1c_miri/jw02044006001_06101_00002_mirimage_rate.fits ...
# 2023-06-15 12:03:05,258 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_rate.fits>,).
# 2023-06-15 12:03:05,258 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'assign_wcs', 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2023-06-15 12:03:05,467 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 1.000020129530653
# 2023-06-15 12:03:05,471 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a MIRI mir_lrs-fixedslit pipeline with references {'distortion': '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_distortion_0047.asdf', 'filteroffset': None, 'specwcs': '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_specwcs_0005.fits', 'regions': None, 'wavelengthrange': None, 'camera': None, 'collimator': None, 'disperser': None, 'fore': None, 'fpa': None, 'msa': None, 'ote': None, 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2023-06-15 12:03:05,522 - stpipe.Spec2Pipeline.assign_wcs - INFO - Update S_REGION to POLYGON ICRS  201.298020664 -64.940060828 201.298020664 -64.939574272 201.301159532 -64.939574272 201.301159532 -64.940060828
# 2023-06-15 12:03:05,523 - stpipe.Spec2Pipeline.assign_wcs - INFO - assign_wcs updated S_REGION to POLYGON ICRS  201.298020664 -64.940060828 201.298020664 -64.939574272 201.301159532 -64.939574272 201.301159532 -64.940060828
# 2023-06-15 12:03:05,523 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2023-06-15 12:03:05,667 - stpipe.Spec2Pipeline.assign_wcs - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_assign_wcs.fits
# 2023-06-15 12:03:05,667 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2023-06-15 12:03:05,780 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_assign_wcs.fits>, []).
# 2023-06-15 12:03:05,780 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'imprint_subtract', 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:05,781 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2023-06-15 12:03:05,782 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2023-06-15 12:03:05,892 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args ('data/yses1c_miri/jw02044006001_06101_00001_mirimage_rate.fits', []).
# 2023-06-15 12:03:05,893 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'imprint_subtract', 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:05,893 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2023-06-15 12:03:05,893 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2023-06-15 12:03:06,004 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_assign_wcs.fits>, ['data/yses1c_miri/jw02044006001_06101_00001_mirimage_rate.fits']).
# 2023-06-15 12:03:06,005 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'bsub', 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2023-06-15 12:03:06,054 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Accumulate bkg from data/yses1c_miri/jw02044006001_06101_00001_mirimage_rate.fits
# 2023-06-15 12:03:06,093 - stpipe.Spec2Pipeline.bkg_subtract - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/astropy/stats/sigma_clipping.py:367: AstropyUserWarning: Input data contains invalid values (NaNs or infs), which were automatically clipped.
#   warnings.warn(
#
# 2023-06-15 12:03:06,346 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_bsub.fits
# 2023-06-15 12:03:06,347 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2023-06-15 12:03:06,460 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_bsub.fits>,).
# 2023-06-15 12:03:06,461 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'msa_flagging', 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:06,461 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2023-06-15 12:03:06,463 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2023-06-15 12:03:06,572 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_bsub.fits>,).
# 2023-06-15 12:03:06,572 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'srctype', 'search_output_file': True, 'input_dir': '', 'source_type': 'POINT'}
# 2023-06-15 12:03:06,577 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:06,577 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2023-06-15 12:03:06,578 - stpipe.Spec2Pipeline.srctype - WARNING - Based on user-input, setting SRCTYPE = POINT
# 2023-06-15 12:03:06,580 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2023-06-15 12:03:06,691 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_bsub.fits>,).
# 2023-06-15 12:03:06,691 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'straylight', 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:06,692 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2023-06-15 12:03:06,693 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2023-06-15 12:03:06,801 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_bsub.fits>,).
# 2023-06-15 12:03:06,802 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'flat_field', 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2023-06-15 12:03:06,884 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:06,885 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:06,885 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:06,903 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-06-15 12:03:07,152 - stpipe.Spec2Pipeline.flat_field - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_flat_field.fits
# 2023-06-15 12:03:07,153 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2023-06-15 12:03:07,269 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_flat_field.fits>,).
# 2023-06-15 12:03:07,270 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'fringe', 'search_output_file': True, 'input_dir': ''}
# 2023-06-15 12:03:07,270 - stpipe.Spec2Pipeline.fringe - INFO - Step skipped.
# 2023-06-15 12:03:07,272 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2023-06-15 12:03:07,383 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_flat_field.fits>,).
# 2023-06-15 12:03:07,384 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'pathloss', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2023-06-15 12:03:07,394 - stpipe.Spec2Pipeline.pathloss - INFO - Using PATHLOSS reference file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_pathloss_0001.fits
# 2023-06-15 12:03:07,417 - stpipe.Spec2Pipeline.pathloss - INFO - Input exposure type is MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:07,769 - stpipe.Spec2Pipeline.pathloss - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_pathloss.fits
# 2023-06-15 12:03:07,770 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2023-06-15 12:03:07,882 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_pathloss.fits>,).
# 2023-06-15 12:03:07,883 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'barshadow', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2023-06-15 12:03:07,884 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2023-06-15 12:03:07,885 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2023-06-15 12:03:07,998 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_pathloss.fits>,).
# 2023-06-15 12:03:07,999 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'photom', 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}
# 2023-06-15 12:03:08,016 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_photom_0085.fits
# 2023-06-15 12:03:08,016 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2023-06-15 12:03:08,077 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2023-06-15 12:03:08,078 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIMAGE
# 2023-06-15 12:03:08,078 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:08,078 - stpipe.Spec2Pipeline.photom - INFO -  filter: P750L
# 2023-06-15 12:03:08,094 - stpipe.Spec2Pipeline.photom - INFO -  subarray: FULL
# 2023-06-15 12:03:08,095 - stpipe.Spec2Pipeline.photom - INFO - PHOTMJSR value: 13.7913
# 2023-06-15 12:03:08,300 - stpipe.Spec2Pipeline.photom - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_photom.fits
# 2023-06-15 12:03:08,301 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2023-06-15 12:03:08,415 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe running with args (<ImageModel(1024, 1032) from jw02044006001_06101_00002_mirimage_photom.fits>,).
# 2023-06-15 12:03:08,416 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'residual_fringe', 'search_output_file': False, 'input_dir': '', 'save_intermediate_results': False, 'ignore_region_min': None, 'ignore_region_max': None}
# 2023-06-15 12:03:08,416 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step skipped.
# 2023-06-15 12:03:08,418 - stpipe.Spec2Pipeline.residual_fringe - INFO - Step residual_fringe done
# 2023-06-15 12:03:08,590 - stpipe.Spec2Pipeline.resample_spec - INFO - Step resample_spec running with args (<ImageModel(1024, 1032) from stage2/jw02044006001_06101_00002_mirimage_cal.fits>,).
# 2023-06-15 12:03:08,591 - stpipe.Spec2Pipeline.resample_spec - INFO - Step resample_spec parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': True, 'suffix': 's2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2023-06-15 12:03:08,592 - stpipe.Spec2Pipeline.resample_spec - INFO - Step skipped.
# 2023-06-15 12:03:08,593 - stpipe.Spec2Pipeline.resample_spec - INFO - Step resample_spec done
# 2023-06-15 12:03:08,768 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<ImageModel(1024, 1032) from stage2/jw02044006001_06101_00002_mirimage_cal.fits>,).
# 2023-06-15 12:03:08,769 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-06-15 12:03:08,780 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2023-06-15 12:03:08,786 - stpipe.Spec2Pipeline.extract_1d - INFO - Using APCORR file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_apcorr_0007.fits
# 2023-06-15 12:03:08,810 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2023-06-15 12:03:08,811 - stpipe.Spec2Pipeline.extract_1d - INFO - Processing spectral order 1
# 2023-06-15 12:03:08,811 - stpipe.Spec2Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_LRS-FIXEDSLIT
# 2023-06-15 12:03:08,822 - stpipe.Spec2Pipeline.extract_1d - INFO - Applying position offset of 7.54 to xstart and xstop
# 2023-06-15 12:03:08,822 - stpipe.Spec2Pipeline.extract_1d - INFO - Using extraction limits: xstart=327.0389723040606, xstop=337.0389723040606, ystart=6, ystop=395
# 2023-06-15 12:03:08,827 - stpipe.Spec2Pipeline.extract_1d - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/extract_1d/extract.py:1901: RuntimeWarning: Mean of empty slice
#   wavelength = np.nanmean(wl[sy0:sy1, sx0:sx1], axis=1)
#
# 2023-06-15 12:03:08,884 - stpipe.Spec2Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2023-06-15 12:03:09,081 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_x1d.fits
# 2023-06-15 12:03:09,081 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-06-15 12:03:09,081 - stpipe.Spec2Pipeline - INFO - Finished processing product jw02044006001_06101_00002_mirimage_rate.fits
# 2023-06-15 12:03:09,082 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2023-06-15 12:03:09,082 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1084.pmap
# 2023-06-15 12:03:09,082 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1084.pmap
# 2023-06-15 12:03:09,287 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw02044006001_06101_00001_mirimage_cal.fits
# 2023-06-15 12:03:09,467 - stpipe.Spec2Pipeline - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_cal.fits
# 2023-06-15 12:03:09,467 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# By default, the Spec2Pipeline for LRS slit will return files of types:
# * ``cal.fits``: photometrically calibrated 2D spectral images, FULL array, not rectified (output from the photom step)
# * ``s2d.fits``: photometrically calibrated 2D spectral images, cutout, rectified (output from the resample_spec step)
# * ``x1d.fits``: 1D extracted spectra for each nod position
#
# Let's take a look at the resampled 2d products, and at the 1D spectra that were extracted from them. **We can already see here that the automated extraction has not worked properly. The two spectra should be near-identical and they are not! Plus the fluxes are very low, when we are expecting a healthy SNR spectrum.**

# %%
sp2_s2dfiles = glob('stage2/jw02044*s2d.fits')
#sp2_s2dfiles.reverse()
print(sp2_s2dfiles)

fig2a, ax2a = plt.subplots(ncols=2, figsize=[8,10])
for sdf, ax in zip(sp2_s2dfiles, ax2a):
    im = datamodels.open(sdf)
    ll = (sdf.split('/')[-1]).split('.')[0]
    ax.imshow(im.data, origin='lower', cmap='gist_heat', vmin=-100, vmax=100)
    ax.set_title(ll, fontsize='small')
    ax.set_xlabel('col')
    ax.set_ylabel('row')

fig2a.show()
# Out:
# 2023-06-14 15:13:51,647 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/2671239304.py:14: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig2a.show()
# ['stage2/jw02044006001_06101_00002_mirimage_s2d.fits', 'stage2/jw02044006001_06101_00001_mirimage_s2d.fits']

# %%
sp2_calfiles = glob('stage2/jw02044*cal.fits')
#sp2_s2dfiles.reverse()
print(sp2_calfiles)

fig2b, ax2b = plt.subplots(ncols=2, figsize=[8,10])
for sdf, ax in zip(sp2_calfiles, ax2b):
    im = datamodels.open(sdf)
    ll = (sdf.split('/')[-1]).split('.')[0]
    ax.imshow(im.data, origin='lower', cmap='gist_heat', vmin=-100, vmax=100)
    ax.set_title(ll, fontsize='small')
    ax.set_ylim(0,400)
    ax.set_xlim(300,350)
#     ax.set_xlabel('col')
#     ax.set_ylabel('row')

fig2b.show()
# Out:
# ['stage2/jw02044006001_06101_00002_mirimage_cal.fits', 'stage2/jw02044006001_06101_00001_mirimage_cal.fits']
# 2023-06-14 15:13:57,859 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/790830026.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig2b.show()

# %%
sp2_x1dfiles = glob('stage2/jw02044*x1d.fits')
print(sp2_x1dfiles)
fig2b, ax2b = plt.subplots(figsize=[12,6])
for spf in sp2_x1dfiles:
    sp = datamodels.open(spf)
    print(sp.meta.ref_file.crds.context_used)
    ll = (spf.split('/')[-1]).split('.')[0]
    ax2b.plot(sp.spec[0].spec_table['WAVELENGTH'], sp.spec[0].spec_table['FLUX'], label=ll)
#     ax2b.plot(sp.spec[0].spec_table['WAVELENGTH'], sp.spec[0].spec_table['FLUX']+sp.spec[0].spec_table['FLUX_ERROR'], label=ll)
#ax2.plot(l3_spec.spec[0].spec_table['WAVELENGTH'], l3_spec.spec[0].spec_table['FLUX'], 'r-', label='default L3 spectrum')
ax2b.legend()
ax2b.set_xlabel('wavelength (um)')
ax2b.set_ylabel('flux (Jy)')
ax2b.set_xlim(5., 14.)
ax2b.set_ylim(-0.00015,0.00015)
fig2b.show()
# Out:
# 2023-06-21 12:18:43,649 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/3002148420.py:16: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig2b.show()
# ['stage2/jw02044006001_06101_00002_mirimage_x1d.fits', 'stage2/jw02044006001_06101_00001_mirimage_x1d.fits']
# jwst_1084.pmap
# jwst_1084.pmap

# %%
##try to mask out NANs and extract a better spectra
from astropy.io import fits
from astropy.table import Table
from astropy.visualization import simple_norm

cal_nod1 = datamodels.open('stage2/jw02044006001_06101_00002_mirimage_cal.fits')
cal_nod1_o = datamodels.open('stage2/jw02044006001_06101_00001_mirimage_cal.fits')


# cal_nod = fits.open("stage2/jw02044006001_06101_00002_mirimage_cal.fits")
# cal_nod_data = cal_nod['SCI'].data

# %%
##try to mask out NANs and extract a better spectra
from astropy.io import fits
from astropy.table import Table
from astropy.visualization import simple_norm

cal_nod1 = datamodels.open('stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits')
cal_nod1_o = datamodels.open('stage2/yses1c/jw02044006001_06101_00001_mirimage_cal.fits')


cal_nod = fits.open("stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits")
cal_nod_data = cal_nod['SCI'].data
cal_nod['SCI'].data = cal_nod1.data
cal_nod_mod = cal_nod.writeto('stage2/yses1c/jw02044006001_06101_00002_mirimage_cal_mod.fits',overwrite=True)

#try masking NANs
mask = np.isnan(cal_nod1.data)
cal_nod1.data[mask] = np.interp(np.flatnonzero(mask), np.flatnonzero(~mask), cal_nod1.data[~mask])
cal_nod1.dq[mask]=0

cal_nod = fits.open("stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits")
# cal_nod_data = cal_nod['SCI'].data
cal_nod['SCI'].data = cal_nod1.data


# mask2 = np.isnan(cal_nod_data)
# cal_nod_data[mask2] = np.interp(np.flatnonzero(mask2), np.flatnonzero(~mask2), cal_nod_data[~mask2])
# # cal_nod['SCI'].data = cal_nod_data

cal_nod_mod = cal_nod.writeto('stage2/yses1c/jw02044006001_06101_00002_mirimage_cal_mod.fits',overwrite=True)

plt.figure(figsize=[8,10])
plt.imshow(cal_nod1.data,origin='lower', cmap='gist_heat', vmin=-100, vmax=100)
plt.xlim([300,350])
plt.ylim([0,400])


plt.axvline(333)

plt.show()

plt.figure()
plt.plot(cal_nod1.data[0:400,333:336])
plt.xlim([400,0])
plt.ylim([0,100])
# plt.imshow(cal_nod1_o.data,origin='lower', cmap='gist_heat', vmin=-100, vmax=100)
# plt.xlim([300,350])
# plt.ylim([0,400])
# plt.show()
# Out:
# 2023-06-21 12:25:39,998 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/2661701741.py:10: ResourceWarning: unclosed file <_io.BufferedReader name='stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits'>
#   cal_nod = fits.open("stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits")
#
# 2023-06-21 12:25:40,090 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/2661701741.py:20: ResourceWarning: unclosed file <_io.BufferedReader name='stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits'>
#   cal_nod = fits.open("stage2/yses1c/jw02044006001_06101_00002_mirimage_cal.fits")
# (0.0, 100.0)

# %%
spec = cal_nod1.data[0:400,331:337].sum(axis=1)
spec.shape
plt.plot(spec)
plt.xlim([400,0])
plt.ylim(0,)
plt.show()

plt.plot(cal_nod1.data[300,300:350],marker='o')
plt.axvline(34)
plt.axvline(31)
plt.axvline(37)

# %%
# spec2.extract_1d(cal_nod1)
spec2.extract_1d('stage2/yses1c/jw02044006001_06101_00002_mirimage_cal_mod.fits')
spec2.extract_1d.save_results = True


filename = 'stage2/jw02044006001_06101_00002_mirimage_x1d.fits'
fig2b, ax2b = plt.subplots(figsize=[12,6])
sp = datamodels.open(filename)
print(sp.meta.ref_file.crds.context_used)
ll = (filename.split('/')[-1]).split('.')[0]
ax2b.plot(sp.spec[0].spec_table['WAVELENGTH'], sp.spec[0].spec_table['FLUX'], label=ll)
ax2b.legend()
ax2b.set_xlabel('wavelength (um)')
ax2b.set_ylabel('flux (Jy)')
ax2b.set_xlim(5., 14.)
ax2b.set_ylim(-0.00015,0.00015)
# Out:
# 2023-06-21 12:25:46,293 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args ('stage2/yses1c/jw02044006001_06101_00002_mirimage_cal_mod.fits',).
# 2023-06-21 12:25:46,294 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': True, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-06-21 12:25:46,428 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2023-06-21 12:25:46,434 - stpipe.Spec2Pipeline.extract_1d - INFO - Using APCORR file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_apcorr_0007.fits
# 2023-06-21 12:25:46,458 - stpipe.Spec2Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2023-06-21 12:25:46,459 - stpipe.Spec2Pipeline.extract_1d - INFO - Processing spectral order 1
# 2023-06-21 12:25:46,459 - stpipe.Spec2Pipeline.extract_1d - INFO - Turning on source position correction for exp_type = MIR_LRS-FIXEDSLIT
# 2023-06-21 12:25:46,471 - stpipe.Spec2Pipeline.extract_1d - INFO - Applying position offset of 7.54 to xstart and xstop
# 2023-06-21 12:25:46,471 - stpipe.Spec2Pipeline.extract_1d - INFO - Using extraction limits: xstart=327.0389723040606, xstop=337.0389723040606, ystart=6, ystop=395
# 2023-06-21 12:25:46,476 - stpipe.Spec2Pipeline.extract_1d - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/extract_1d/extract.py:1901: RuntimeWarning: Mean of empty slice
#   wavelength = np.nanmean(wl[sy0:sy1, sx0:sx1], axis=1)
#
# 2023-06-21 12:25:46,532 - stpipe.Spec2Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2023-06-21 12:25:46,732 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in stage2/jw02044006001_06101_00002_mirimage_x1d.fits
# 2023-06-21 12:25:46,733 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# jwst_1084.pmap
# (-0.00015, 0.00015)

# %%
plt.imshow(mask,origin='lower')
print(mask)
# Out:
# [[ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  ...
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]
#  [ True  True  True ...  True  True  True]]

# %%
cal_nod1.data.shape
# mask.shape
# Out:
# (1024, 1032)

# %%
fits.info('stage2/yses1c/jw02044006001_06101_00002_mirimage_cal_mod.fits')
# Out:
# Filename: stage2/yses1c/jw02044006001_06101_00002_mirimage_cal_mod.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     336   ()
#   1  SCI           1 ImageHDU        69   (1039916,)   float32
#   2  ERR           1 ImageHDU        10   (1032, 1024)   float32
#   3  DQ            1 ImageHDU        11   (1032, 1024)   int32 (rescales to uint32)
#   4  WAVELENGTH    1 ImageHDU         9   (1032, 1024)   float32
#   5  VAR_POISSON    1 ImageHDU         9   (1032, 1024)   float32
#   6  VAR_RNOISE    1 ImageHDU         9   (1032, 1024)   float32
#   7  VAR_FLAT      1 ImageHDU         9   (1032, 1024)   float32
#   8  PATHLOSS_PS    1 ImageHDU         9   (1032, 1024)   float32
#   9  ASDF          1 BinTableHDU     11   1R x 1C   [58391B]

# %%
# checking SNR
plt.plot(sp.spec[0].spec_table['WAVELENGTH'], sp.spec[0].spec_table['FLUX']/sp.spec[0].spec_table['FLUX_ERROR'], label=ll)

# %% [markdown]
# ### Note
# The extracted products at Level 2 of the pipeline are not yet "final". They are more affected by bad pixels and detector artifacts than the final Level 3 product. They are useful for quick-look purposes or to diagnose problems, but for full science-ready spectra, you should perform the Level 3 processing.
#
# **The spectra we see from Level 2 are a sign that there is some coordinate issue that is preventing the automated extraction from working. In the next step we will perform the Spec3Pipeline processing and fix this issue to get a science-ready spectrum**

# %% [markdown]
# # Spec3Pipeline
#
# The Level 3 pipeline combines the 2 nod images, which reduces the impact of bad pixels and provides better signal to noise; and performs the final "science-ready" extraction. Whereas the Spec2Pipeline can take both single files and associations as input, the Spec3Pipeline always requires an association as input.
#
# In the code below we repeat the association creation, and run the Spec3Pipeline. To ensure that the extraction aperture is placed in the correct position, we use a custom extraction reference file, ``miri_lrs_demo_extract1d.json``, that forces the pipeline to extract specific columns. You can adapt this reference file for your own science, definining custom extraction apertures and extraction limits. The file can also be used to specify:
#
# - tapered column extraction (with linear or polynomial-shaped edges)
# - background subtraction from an off-target portion of the array
#
#
# and more. For full details of all the options for this reference file, see the [documentation pages](https://jwst-pipeline.readthedocs.io/en/latest/jwst/extract_1d/reference_files.html#extract1d-reference-file).

# %%
from jwst.associations.lib.rules_level3_base import DMS_Level3_Base

# %%
asn3 = asn_from_list(sp2_s2dfiles, rule=DMS_Level3_Base, product_name='PID2044_LRS', meta={'program':'02044', 'target':'YSES1c', 'asn_pool':'None'})

with open('lrs_slit_test_spec3asn.json', 'w') as fp:
    fp.write(asn3.dump()[1])
# Out:
# 2023-06-14 12:21:38,410 - stpipe - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)

# %%
spec3 = Spec3Pipeline()
spec3.save_results = True
spec3.output_dir = 'stage3/'
spec3.extract_1d.override_extract1d = 'miri_lrs_demo_extract1d.json'
spec3.extract_1d.use_source_posn = False

sp3 = spec3.run('lrs_slit_test_spec3asn.json')
# Out:
# 2023-06-14 12:22:28,834 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2023-06-14 12:22:28,835 - stpipe.Spec3Pipeline.assign_mtwcs - INFO - AssignMTWcsStep instance created.
# 2023-06-14 12:22:28,836 - stpipe.Spec3Pipeline.master_background - INFO - MasterBackgroundStep instance created.
# 2023-06-14 12:22:28,837 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2023-06-14 12:22:28,839 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2023-06-14 12:22:28,841 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2023-06-14 12:22:28,842 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2023-06-14 12:22:28,844 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2023-06-14 12:22:28,845 - stpipe.Spec3Pipeline.photom - INFO - PhotomStep instance created.
# 2023-06-14 12:22:28,846 - stpipe.Spec3Pipeline.combine_1d - INFO - Combine1dStep instance created.
# 2023-06-14 12:22:28,919 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args ('lrs_slit_test_spec3asn.json',).
# 2023-06-14 12:22:28,924 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': 'stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'steps': {'assign_mtwcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'assign_mtwcs', 'search_output_file': True, 'input_dir': ''}, 'master_background': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'user_background': None, 'save_background': False, 'force_subtract': False}, 'mrs_imatch': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'bkg_degree': 1, 'subtract': False}, 'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'resample_spec': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}, 'cube_build': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 's3d', 'search_output_file': False, 'input_dir': '', 'channel': 'all', 'band': 'all', 'grating': 'all', 'filter': 'all', 'output_type': 'band', 'scale1': 0.0, 'scale2': 0.0, 'scalew': 0.0, 'weighting': 'drizzle', 'coord_system': 'skyalign', 'rois': 0.0, 'roiw': 0.0, 'weight_power': 2.0, 'wavemin': None, 'wavemax': None, 'single': False, 'skip_dqflagging': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': False, 'center_xy': None, 'apply_apcorr': True, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False ...
# 2023-06-14 12:22:28,996 - stpipe.Spec3Pipeline - INFO - Prefetching reference files for dataset: 'jw02044006001_06101_00002_mirimage_s2d.fits' reftypes = ['apcorr', 'area', 'cubepar', 'drizpars', 'photom', 'speckernel', 'specprofile', 'spectrace', 'wavemap']
# 2023-06-14 12:22:29,004 - stpipe.Spec3Pipeline - INFO - Prefetch for APCORR reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_apcorr_0007.fits'.
# 2023-06-14 12:22:29,004 - stpipe.Spec3Pipeline - INFO - Prefetch for AREA reference file is 'N/A'.
# 2023-06-14 12:22:29,004 - stpipe.Spec3Pipeline - INFO - Prefetch for CUBEPAR reference file is 'N/A'.
# 2023-06-14 12:22:29,005 - stpipe.Spec3Pipeline - INFO - Prefetch for DRIZPARS reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_drizpars_0001.fits'.
# 2023-06-14 12:22:29,005 - stpipe.Spec3Pipeline - INFO - Override for EXTRACT1D reference file is '/Users/khoch/Desktop/Research/TYC_YSES1_PROG/miri_lrs_demo_extract1d.json'.
# 2023-06-14 12:22:29,005 - stpipe.Spec3Pipeline - INFO - Prefetch for PHOTOM reference file is '/Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_photom_0085.fits'.
# 2023-06-14 12:22:29,006 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2023-06-14 12:22:29,006 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2023-06-14 12:22:29,006 - stpipe.Spec3Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2023-06-14 12:22:29,006 - stpipe.Spec3Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2023-06-14 12:22:29,007 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2023-06-14 12:22:29,015 - stpipe.Spec3Pipeline - WARNING - /Users/khoch/miniconda3/envs/py38/lib/python3.8/site-packages/jwst/associations/association.py:215: UserWarning: 'expname' contains path, but should only be a filename.  All input files should be in a single directory, so no path is needed.
#   warnings.warn(err_str, UserWarning)
#
# 2023-06-14 12:22:29,210 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2023-06-14 12:22:29,211 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'crf', 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2023-06-14 12:22:29,214 - stpipe.Spec3Pipeline.outlier_detection - INFO - Performing outlier detection on 2 inputs
# 2023-06-14 12:22:29,338 - stpipe.Spec3Pipeline.outlier_detection - INFO - Driz parameter kernal: square
# 2023-06-14 12:22:29,342 - stpipe.Spec3Pipeline.outlier_detection - INFO - Driz parameter pixfrac: 1.0
# 2023-06-14 12:22:29,346 - stpipe.Spec3Pipeline.outlier_detection - INFO - Driz parameter fillval: INDEF
# 2023-06-14 12:22:29,347 - stpipe.Spec3Pipeline.outlier_detection - INFO - Driz parameter weight_type: ivm
# 2023-06-14 12:22:29,439 - stpipe.Spec3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2023-06-14 12:22:29,480 - stpipe.Spec3Pipeline.outlier_detection - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:29,561 - stpipe.Spec3Pipeline.outlier_detection - INFO - Exposure jw02044006001_06101_00002_mirimage_outlier_i2d.fits saved to file
# 2023-06-14 12:22:29,568 - stpipe.Spec3Pipeline.outlier_detection - INFO - 1 exposures to drizzle together
# 2023-06-14 12:22:29,604 - stpipe.Spec3Pipeline.outlier_detection - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:29,666 - stpipe.Spec3Pipeline.outlier_detection - INFO - Exposure jw02044006001_06101_00001_mirimage_outlier_i2d.fits saved to file
# 2023-06-14 12:22:30,095 - stpipe.Spec3Pipeline.outlier_detection - INFO - Blotting median...
# 2023-06-14 12:22:30,132 - stpipe.Spec3Pipeline.outlier_detection - INFO - Blotting (387, 44) <-- (388, 61)
# 2023-06-14 12:22:30,239 - stpipe.Spec3Pipeline.outlier_detection - INFO - Blotting (387, 44) <-- (388, 61)
# 2023-06-14 12:22:30,309 - stpipe.Spec3Pipeline.outlier_detection - INFO - Flagging outliers
# 2023-06-14 12:22:30,403 - stpipe.Spec3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 78 (0.46%)
# 2023-06-14 12:22:30,495 - stpipe.Spec3Pipeline.outlier_detection - INFO - New pixels flagged as outliers: 172 (1.01%)
# 2023-06-14 12:22:30,568 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw02044006001_06101_00002_mirimage_a3001_crf.fits
# 2023-06-14 12:22:30,639 - stpipe.Spec3Pipeline.outlier_detection - INFO - Saved model in stage3/jw02044006001_06101_00001_mirimage_a3001_crf.fits
# 2023-06-14 12:22:30,639 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2023-06-14 12:22:30,718 - stpipe.Spec3Pipeline.resample_spec - INFO - Step resample_spec running with args (<ModelContainer>,).
# 2023-06-14 12:22:30,719 - stpipe.Spec3Pipeline.resample_spec - INFO - Step resample_spec parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 's2d', 'search_output_file': True, 'input_dir': '', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'weight_type': 'ivm', 'output_shape': None, 'crpix': None, 'crval': None, 'rotation': None, 'pixel_scale_ratio': 1.0, 'pixel_scale': None, 'output_wcs': '', 'single': False, 'blendheaders': True, 'allowed_memory': None, 'in_memory': True}
# 2023-06-14 12:22:30,755 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizpars reference file: /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_drizpars_0001.fits
# 2023-06-14 12:22:30,886 - stpipe.Spec3Pipeline.resample_spec - INFO - Driz parameter kernal: square
# 2023-06-14 12:22:30,886 - stpipe.Spec3Pipeline.resample_spec - INFO - Driz parameter pixfrac: 1.0
# 2023-06-14 12:22:30,887 - stpipe.Spec3Pipeline.resample_spec - INFO - Driz parameter fillval: INDEF
# 2023-06-14 12:22:30,889 - stpipe.Spec3Pipeline.resample_spec - INFO - Driz parameter weight_type: ivm
# 2023-06-14 12:22:30,937 - stpipe.Spec3Pipeline.resample_spec - INFO - Blending metadata for PID2044_LRS
# 2023-06-14 12:22:31,437 - stpipe.Spec3Pipeline.resample_spec - INFO - Resampling science data
# 2023-06-14 12:22:31,444 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,454 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,456 - stpipe.Spec3Pipeline.resample_spec - INFO - Resampling var_rnoise
# 2023-06-14 12:22:31,464 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,473 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,477 - stpipe.Spec3Pipeline.resample_spec - INFO - Resampling var_poisson
# 2023-06-14 12:22:31,484 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,494 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,498 - stpipe.Spec3Pipeline.resample_spec - INFO - Resampling var_flat
# 2023-06-14 12:22:31,505 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,515 - stpipe.Spec3Pipeline.resample_spec - INFO - Drizzling (387, 44) --> (388, 61)
# 2023-06-14 12:22:31,530 - stpipe.Spec3Pipeline.resample_spec - INFO - Update S_REGION to POLYGON ICRS  201.297068248 -64.939958926 201.301154016 -64.939958926 201.301154016 -64.939325585 201.297068248 -64.939325585
# 2023-06-14 12:22:31,800 - stpipe.Spec3Pipeline.resample_spec - INFO - Saved model in stage3/PID2044_LRS_s2d.fits
# 2023-06-14 12:22:31,800 - stpipe.Spec3Pipeline.resample_spec - INFO - Step resample_spec done
# 2023-06-14 12:22:31,877 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<SlitModel(388, 61) from PID2044_LRS_s2d.fits>,).
# 2023-06-14 12:22:31,878 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': 'x1d', 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': None, 'use_source_posn': False, 'center_xy': None, 'apply_apcorr': True, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-06-14 12:22:31,909 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/khoch/Desktop/Research/TYC_YSES1_PROG/miri_lrs_demo_extract1d.json
# 2023-06-14 12:22:31,940 - stpipe.Spec3Pipeline.extract_1d - INFO - Using APCORR file /Users/khoch/crds_cache/jwst_ops/references/jwst/miri/jwst_miri_apcorr_0007.fits
# 2023-06-14 12:22:31,965 - stpipe.Spec3Pipeline.extract_1d - WARNING - spectral_order is None; using 1
# 2023-06-14 12:22:31,965 - stpipe.Spec3Pipeline.extract_1d - INFO - Processing spectral order 1
# 2023-06-14 12:22:31,972 - stpipe.Spec3Pipeline.extract_1d - INFO - Using extraction limits: xstart=27, xstop=34, ystart=0, ystop=387
# 2023-06-14 12:22:32,023 - stpipe.Spec3Pipeline.extract_1d - INFO - Applying Aperture correction.
# 2023-06-14 12:22:32,227 - stpipe.Spec3Pipeline.extract_1d - INFO - Saved model in stage3/PID2044_LRS_x1d.fits
# 2023-06-14 12:22:32,227 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-06-14 12:22:32,228 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2023-06-14 12:22:32,229 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %%
sp3_s2dfiles = glob('stage3/PID2044*s2d.fits')

fig3a, ax3a = plt.subplots(figsize=[4,10])
im = datamodels.open(sp3_s2dfiles[0])
ax3a.imshow(im.data, origin='lower', cmap='gist_heat',vmin=-100,vmax=100)
ax3a.set_title(sp3_s2dfiles[0].split('/')[-1])
fig3a.show()
# Out:
# 2023-06-14 12:23:11,958 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/2933666819.py:7: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig3a.show()

# %%
sp3_x1dfile = 'stage3/PID2044_LRS_x1d.fits'


fig3b, ax3b = plt.subplots(figsize=[12,6])

for spf in sp2_x1dfiles:
    sp = datamodels.open(spf)
    ll = (spf.split('/')[-1]).split('.')[0] + ' (Level 2b, automated)'
    ax3b.plot(sp.spec[0].spec_table['WAVELENGTH'], sp.spec[0].spec_table['FLUX'], label=ll)
    
sp3_x1d = datamodels.open(sp3_x1dfile)
ll3 = (sp3_x1dfile.split('/')[-1]).split('.')[0] + ' (Level 3, custom)'
ax3b.plot(sp3_x1d.spec[0].spec_table['WAVELENGTH'], sp3_x1d.spec[0].spec_table['FLUX'], label=ll3)

ax3b.legend()
ax3b.set_xlabel('wavelength (um)')
ax3b.set_ylabel('flux (Jy)')
ax3b.set_xlim(5., 14.)
ax3b.set_ylim(-0.00015,0.00015)
fig3b.show()
# Out:
# 2023-06-14 12:25:04,545 - stpipe - WARNING - /var/folders/2c/mz91lpj55637w19c67bpjpy40002dz/T/ipykernel_1975/1476773935.py:20: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig3b.show()

# %% [markdown]
# By providing the xstart and xstop limits for the spectral extraction in the custom reference file, and setting the ``use_source_posn`` to False, we prevent the pipeline from using coordinates to place the apertue and instead force it to use our column limits. As a result we get a much cleaner spectrum.
#
# In the reference file update for CRDS context 1088, the ``use_source_posn`` setting is inlcluded in the extractino reference file.
#
# **Note**: a custom reference file can be provided for the spectral extraction in the Spec2Pipeline, exactly as we did for the Spec3Pipeline run. However this requires the ``extract_1d`` step to be run for each nod file individually, with a custom reference file adjusted to the position of the nod in the field.
#
# #### Please contact the [JWST Helpdesk](https://stsci.service-now.com/jwst) if you have any questions or problems!
#
# -- END
#
# SK, May 31st 2023
